# %%
# import re

import sys
from datetime import datetime

import requests as r

# %%
first_bank = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBgu2abmqk202203249586"
access_bank = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB2kug63rt202203814200"
gt_bank = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBido4xo6720220411202755"
keystone_bank_1 = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBqho5jf19202204617034"
keystone_bank_2 = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBx3zu9cil202205177018"
poliaris_1 = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB5re47yqf2022047231557"
poliaris_2 = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB7dxrbtnv20220410151115"
sterling = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBlsl4tvra2022041114058"
standard = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBmib4r9ss20220478215"
uba = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBrefruh08202204484746"
union_bank = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBkcboxo2i2022046231250"
wema_bank = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSByooviikl2022032312748"
zenith = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBir4ngg1v2022032882648"
zenith_2 = "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBqoixnexo2022041213740"

bank_urls = {
    "first_bank": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBgu2abmqk202203249586",
    "access_bank": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB2kug63rt202203814200",
    "gt_bank": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBido4xo6720220411202755",
    "keystone_bank_1": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBqho5jf19202204617034",
    "keystone_bank_2": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBx3zu9cil202205177018",
    "poliaris_1": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB5re47yqf2022047231557",
    "poliaris_2": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSB7dxrbtnv20220410151115",
    "sterling": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBlsl4tvra2022041114058",
    "standard": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBmib4r9ss20220478215",
    "uba": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBrefruh08202204484746",
    "union_bank": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBkcboxo2i2022046231250",
    "wema_bank": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSByooviikl2022032312748",
    "zenith": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBir4ngg1v2022032882648",
    "zenith_2": "https://worker-service-prod.herokuapp.com/transactions/fetch/mystash/MSBqoixnexo2022041213740"
}

# %% [raw]
# messages = {}
# for bank, url in bank_urls.items():
#     resp = r.get(url)
#     banks_messages = resp.json()
#     messages[bank] = banks_messages

# %%
def entry(payload):
    """
    send request to a handler
    
    assume request looks like this:
        {
            "uid": string,
            "sender": string,
            "message": string,
            "date": datetime
        }
    """
    selected_handler = handlers.get(payload['sender'], None)
    if selected_handler:
        handler = selected_handler(payload)
        return handler.process()
    else:
        return {
            "error": f"no handler for {payload['sender']}"
        }

text = "Acct: **5287\nDR: NGN5,500.00, COM+VAT:26.88\nDesc: MOBILE/UNION Transfer to Chisom Chisom Okpara - NA\nDT: 12/APR/2022 17:00:01\nAvailable Bal: NGN61,113.99CR"
text.split('\n')
# Out:
# ['Acct: **5287',
#  'DR: NGN5,500.00, COM+VAT:26.88',
#  'Desc: MOBILE/UNION Transfer to Chisom Chisom Okpara - NA',
#  'DT: 12/APR/2022 17:00:01',
#  'Available Bal: NGN61,113.99CR']

# %%
class Handler:
    def __init__(self, payload):
        assert type(payload) is dict
        self.payload = payload
        self.uid = self.payload.get('uid', None)
        self.sender = self.payload.get('sender', None)
        self.message = self.payload.get('message')
        self.date = self.payload.get('date', None)
        
        self.empty = {
            "bank": "bank",
            "tx_type": "",
            "amount": "",
            "currency": "",
            "account_number": "",
            "datetime": "",
            "description": "",
            "avail_bal": "",
            "message": self.message,
            "error": "could not parse 'message'"
        }

# %%
class FirstBankHandler(Handler):
    """
    Examples:
        Debit: 311XXXX343 Amt: NGN7,000.00 Date: 24-MAR-2022 11:10:20 Desc: FBNMOBILE:Anele Oluebu/MoneyCR Pay and Win with Verve Card
    """
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        tx, acc_no, _, amt, _, date, time, _, *desc = self.message.split(" ")
        
        tx_type = tx[:-1].lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        self.account_number = acc_no
        
        amount = amt[3:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[:3]
        
        date_time = f"{date} {time}"
        self.datetime = datetime.strptime(date_time, '%d-%b-%Y %H:%M:%S')
        
        self.description = ' '.join(desc)
        
        result = {
            "bank": "firstbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description
        }
        
        return result

# %%
class AccessBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        tx, amt, acc_no, desc, date, avail_bal, total = self.message.split("\n")
        
        tx_type = tx.lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
         
        amount = amt[7:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[4:7]
        
        self.account_number = acc_no[4:]
        
        self.description = desc[5:]
        
        date = date[5:]
        self.datetime = datetime.strptime(date, '%d/%m/%Y')
        
        avail_bal = avail_bal[13:].replace(',', '')
        self.avail_bal = float(avail_bal)
        
        total = total[9:].replace(',', '')
        self.total = float(total)
        
        
        result = {
            "bank": "accessbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal,
            "total": self.total
        }
        
        return result

# %%
class GTBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        if not self.message.startswith("Acc"):
            return None
        if "\r" in self.message:
            acc_no, amt_tx, desc, bal, date_time = self.message.split("\r\n")
        else:
            acc_no, amt_tx, desc, bal, date_time = self.message.split("\n")
        
        self.account_number = acc_no[6:]
        
        amount = amt_tx[8:-3].replace(',', '')
        self.amount = float(amount)
        self.currency = amt_tx[5:8]
        
        tx_type = amt_tx[-2:].lower()
        self.tx_type_short = tx_type
        
        self.description = desc[6:]
        
        bal = bal[14:].replace(',', '')
        self.avail_bal = float(bal)
        
        date_time = date_time[6:].title().strip()
        self.datetime = datetime.strptime(date_time, '%d-%b-%Y %H:%M')
        
        result = {
            "bank": "gtbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class KeystoneBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        tx, acc_no, amt, desc, date_time, bal, _ = self.message.split("\n")
        
        tx_type = tx.lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        self.account_number = acc_no[5:]
        
        amount = amt[5:].replace(',', '')
        self.amount = float(amount)
        self.currency = "NGN" if amt[4:5] == "N" else None
        
        self.description = desc[5:]
        
        date_time = date_time[5:]
        self.datetime = datetime.strptime(date_time, '%d-%m-%Y %H:%M')
        
        bal = bal[7:].replace(',', '')
        self.avail_bal = float(bal)
        
        
        result = {
            "bank": "keystone",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class PolarisBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        tx, acc_no, amt, desc, bal, date_time, _ = self.message.split("\n")
        
        tx_type = tx.lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        self.account_number = acc_no[5:]
        
        amount = amt[5:].replace(',', '')
        self.amount = float(amount)
        self.currency = "NGN" if amt[4:5] == "N" else None
        
        self.description = desc[4:]
        
        bal = bal[5:].replace(',', '')
        self.avail_bal = float(bal)
        
        date_time = date_time
        self.datetime = datetime.strptime(date_time, '%d-%m-%Y%H:%M')
        
        
        result = {
            "bank": "polarisbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class SterlingBankHandler(Handler):
    """
    Examples:
    
    Money In Alert. \nNGN11,000.00 has just arrived from Paystack into **9032 at 7:15 AM 19-Apr-2022 \nYou now have: NGN ***."
    
    Money Out Alert!\nAcc#: **9032\nDesc: USSD/Airtime purchased of Amt 200.00 to Mobile 09126922679. RefID: 23\n09-May-2022 @ 5:32 PM\nAmt: NGN 200.00 \nAv.Bal: NGN ***"
    
    Debit Alert!\nAcc#: **9032\nDesc: USSD/Airtime purchased of Amt 200.00 to Mobile 09126308040. RefID: 221473\n22-Apr-2022 @ 7:52 PM\nAmt: NGN 200.00 \nAv.Bal: NGN ***"
    """
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        if self.message.startswith("Money"):
            if "Alert!" in self.message:
                tx, acc_no, desc, date_time, amt, bal, = self.message.split("\n")

                tx_type = tx.split(" ")[1].lower()
                self.tx_type_short = "dr" if tx_type == "out" else "cr"

                self.account_number = acc_no[6:]

                self.description = desc[6:]

                date_time = date_time
                self.datetime = datetime.strptime(date_time, '%d-%b-%Y @ %I:%M %p')

                amount = amt[9:].strip().replace(',', '')
                self.amount = float(amount)
                self.currency = "NGN" if amt[5:8] == "N" else None

                # 'Av.Bal: NGN ***.' is expected
                bal = bal[12:].replace(',', '')
                try:
                    self.avail_bal = float(bal)
                except:
                    self.avail_bal = None
            else:
                tx, detail, balance = self.message.split("\n")

                tx_type = tx.split(" ")[1].lower()
                self.tx_type_short = "dr" if tx_type == "out" else "cr"
                if tx_type == "in":
                    amt, _, _, _, *info = detail.strip().split(" ")
                    date_time = info[-3:]; info = info[:-3]
                    acc_no = info[-2]; info = info[:-3]
                    info = info

                    self.account_number = acc_no

                    amount = amt[3:].replace(',', '')
                    self.amount = float(amount)
                    self.currency = amt[:3]

                    self.description = " ".join(info)

                    date_time = "".join(date_time)
                    self.datetime = datetime.strptime(date_time, '%I:%M%p%d-%b-%Y')

                elif tx_type == "out":
                    _, _, _, amt, *info = detail.strip().split(" ")
                    date_time = info[-3:]; info = info[:-3]
                    acc_no = info[-2]; info = info[:-3]
                    info = info

                    self.account_number = acc_no

                    amount = amt[3:].replace(',', '')
                    self.amount = float(amount)
                    self.currency = amt[:3]

                    self.description = " ".join(info)

                    date_time = "".join(date_time)
                    self.datetime = datetime.strptime(date_time, '%I:%M%p%d-%b-%Y')

                # 'You now have NGN ***.' is expected
                *_, bal = balance.split(" ")
                bal = bal[:-1].replace(',', '')
                try:
                    self.avail_bal = float(bal)
                except:
                    self.avail_bal = None
        else:
            tx, acc_no, desc, date_time, amt, bal, = self.message.split("\n")
        
            tx_type = tx.split(" ")[0].lower()
            self.tx_type_short = "dr" if tx_type == "debit" else "cr"

            self.account_number = acc_no[6:]

            self.description = desc[6:]

            date_time = date_time
            self.datetime = datetime.strptime(date_time, '%d-%b-%Y @ %I:%M %p')

            amount = amt[9:].strip().replace(',', '')
            self.amount = float(amount)
            self.currency = "NGN" if amt[5:8] == "N" else None
            
            # 'Av.Bal: NGN ***.' is expected
            bal = bal[12:].replace(',', '')
            try:
                self.avail_bal = float(bal)
            except:
                self.avail_bal = None

        
        result = {
            "bank": "sterling",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class StandardCharteredHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        if not "Alert!" in self.message:
            return None
        
        tx_acc_no, amt, desc, date_time, bal = self.message.split(", ")
        
        tx, acc_no = tx_acc_no.split(" Alert! ")
        self.account_number = acc_no[5:]
        
        tx_type = tx.lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        amount = amt[7:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[4:7]
        
        self.description = desc[5:]
        
        date_time = date_time[5:]
        self.datetime = datetime.strptime(date_time, '%Y-%m-%d')
        
        bal = bal[7:].replace(',', '')
        self.avail_bal = float(bal)
        
        result = {
            "bank": "stanchart",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class UBAHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        if not self.message.startswith("Txn"):
            return None
        
        tx, acc_no, amt, desc, date_time, bal, _ = self.message.split("\n")
        
        tx_type = tx[5:].lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        self.account_number = acc_no[3:]
        
        amount = amt[8:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[4:7]
        
        self.description = desc[4:]
        
        date_time = date_time[5:]
        self.datetime = datetime.strptime(date_time, '%d-%b-%Y %H:%M')
        
        bal = bal[8:].replace(',', '')
        self.avail_bal = float(bal)
        
        
        result = {
            "bank": "uba",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class UnionBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        acc_no, amt, desc, date_time, bal = self.message.split("\n")
        
        self.account_number = acc_no[5:]
        
        amount = amt[7:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[4:7]
        
        tx_type = amt[:2].lower()
        self.tx_type_short = tx_type
        
        self.description = desc[6:]
        
        date_time = date_time[4:].title()
        self.datetime = datetime.strptime(date_time, '%d/%b/%Y %H:%M:%S')
        
        bal = bal[18:-2].replace(',', '')
        self.avail_bal = float(bal)
        
        
        result = {
            "bank": "unionbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class WemaBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        tx, amt, acc_no, desc, bal, date_time = self.message.split("\r\n")
        
        tx_type = tx[5:].lower()
        self.tx_type_short = "dr" if tx_type == "debit" else "cr"
        
        amount = amt[3:].replace(',', '')
        self.amount = float(amount)
        self.currency = amt[:3]
        
        self.account_number = acc_no[8:]
        
        self.description = desc[7:]
        
        bal = bal[5:].replace(',', '')
        self.avail_bal = float(bal)
        
        date_time = date_time
        self.datetime = datetime.strptime(date_time, '%d-%m-%Y %H:%M')
        
        
        result = {
            "bank": "wemabank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "currency": self.currency,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
class ZenithBankHandler(Handler):
    def __init__(self, request):
        super().__init__(request)
    
    def process(self):
        results = self.string_processor()
        if results:
            return results
        else:
            return self.empty
    
    def string_processor(self):
        if not self.message.startswith("Acc"):
            return None
        
        acc_no, date_time, desc, tx_amt, bal, *_ = self.message.split("\n")
        
        self.account_number = acc_no[5:]
        
        date_time = date_time[3:]
        self.datetime = datetime.strptime(date_time, '%d/%m/%Y:%I:%M:%S%p')
        
        self.description = desc
        
        tx_type = tx_amt[2].lower()
        self.tx_type_short = tx_type
        
        amount = tx_amt[7:].replace(',', '')
        self.amount = float(amount)
        
        bal = bal[4:].replace(',', '')
        self.avail_bal = float(bal)
        
        result = {
            "bank": "zenithbank",
            "tx_type": self.tx_type_short,
            "amount": self.amount,
            "account_number": self.account_number,
            "datetime": self.datetime,
            "description": self.description,
            "avail_bal": self.avail_bal
        }
        
        return result

# %%
handlers = {
    "FirstBank": FirstBankHandler,
    "AccessBank": AccessBankHandler,
    "GTBANK": GTBankHandler,
    "GTBank": GTBankHandler,
    "KEYSTONE": KeystoneBankHandler,
    "PolarisBank": PolarisBankHandler,
    "STERLING": SterlingBankHandler,
    "StanChart": StandardCharteredHandler,
    "UBA": UBAHandler,
    "UNIONBANK": UnionBankHandler,
    "WemaBank": WemaBankHandler,
    "ZENITHBANK": ZenithBankHandler
}

# %%
def test(bank):
    for payload in messages[bank]:
        entry(payload)

# %%
banks = [ 'zenithbank', 'wemabank', 'unionbank', 'uba',  'stanchart', 'sterling', 'polarisbank', 'keystone', 'gtbank', 'accessbank', 'firstbank']
results = {}
errors = []

def test_check():
    for bank in banks:
        print(f"processing {bank}")
        
        resp = r.get(f"https://worker-service-prod.herokuapp.com/transactions/test/processor?bank={bank}&limit=100")
        message_list = resp.json()
        
        parsed_list = []
        count = 1
        for payload in message_list:
            print(f"\t{count} of {len(message_list)}")
            
            try:
                parse_result = entry(payload)
                parsed_list.append(parse_result)
            except:
                print(f"\terror: {payload.get('message')[:40]}")
                e = sys.exc_info()[0]
                errors.append({
                    "bank": bank,
                    "error": e,
                    "input": payload
                })
            count += 1
        
        results[bank] = {
# 	25 of 100
# 	26 of 100
# 	27 of 100
# 	28 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	29 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	30 of 100
# 	31 of 100
# 	32 of 100
# 	33 of 100
# 	34 of 100
# 	35 of 100
# 	36 of 100
# 	37 of 100
# 	38 of 100
# 	39 of 100
# 	error: Use this OTP 357732 to complete transact
# 	40 of 100
# 	41 of 100
# 	42 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	43 of 100
# 	44 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	45 of 100
# 	46 of 100
# 	47 of 100
# 	48 of 100
# 	49 of 100
# 	50 of 100
# 	51 of 100
# 	52 of 100
# 	53 of 100
# 	54 of 100
# 	55 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	56 of 100
# 	57 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	58 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	59 of 100
# 	60 of 100
# 	61 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	62 of 100
# 	63 of 100
# 	64 of 100
# 	65 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	66 of 100
# 	67 of 100
# 	68 of 100
# 	69 of 100
# 	70 of 100
# 	71 of 100
# 	72 of 100
# 	73 of 100
# 	74 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	75 of 100
# 	76 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	77 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	78 of 100
# 	79 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	80 of 100
# 	81 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN
# 	82 of 100
# 	83 of 100
# 	84 of 100
# 	85 of 100
# 	86 of 100
# 	87 of 100
# 	error: Your balance as at 19-Apr-2022 12:56:08
# 	88 of 100
# 	89 of 100
# 	90 of 100
# 	91 of 100
# 	error: Your balance as at 19-Apr-2022 21:22:35
# 	92 of 100
# 	93 of 100
# 	94 of 100
# 	95 of 100
# 	96 of 100
# 	97 of 100
# 	98 of 100
# 	99 of 100
# 	100 of 100
# 	error: *DO NOT DISCLOSE* A pending Debit of NGN

# %%
for bank in results:
    print(f"{bank}\n\t{len(results[bank]['output'])} of {len(results[bank]['input'])}")
# Out:
# zenithbank
# 	25 of 25
# wemabank
# 	24 of 25
# unionbank
# 	22 of 25
# uba
# 	25 of 25
# stanchart
# 	19 of 19
# sterling
# 	6 of 6
# polarisbank
# 	22 of 25
# keystone
# 	17 of 17
# gtbank
# 	25 of 25
# accessbank
# 	25 of 25

# %%
len(errors)
# Out:
# 12

# %%
errors
# Out:
# [{'bank': 'wemabank',
#   'error': ValueError,
#   'input': {'uid': 'k4tkoqyfno522022041082124',
#    'sender': 'WemaBank',
#    'message': 'Get 100% bonus this Easter when you dial *945*9# to top up your MTN Line. T&Cs apply',
#    'date': '2022-04-22T08:42:25.000Z'}},
#  {'bank': 'wemabank',
#   'error': ValueError,
#   'input': {'uid': 'cqttjqvrcrkw2022051695328',
#    'sender': 'WemaBank',
#    'message': 'Wema Debit\nNGN1,000.00\nAcct No:0245****45\nDesc.: ATM WD on 16-05-2022@AFE BABALOLA UNIVE \nBal: 16,924.12\n16-05-2022 03:16',
#    'date': '2022-05-16T14:30:14.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': '999mibgmrgqq2022046224248',
#    'sender': 'UNIONBANK',
#    'message': 'Beware of fraudsters! DO NOT SHARE THIS PIN WITH ANYONE! Kindly use one-time pin 446778 to complete your transaction. Your account may be debited.',
#    'date': '2022-04-11T07:08:03.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': '0dyagab3bpac20220411201644',
#    'sender': 'UNIONBANK',
#    'message': 'Beware of fraudsters! DO NOT SHARE THIS PIN WITH ANYONE! Kindly use one-time pin 621367 to complete your transaction. Your account may be debited.',
#    'date': '2022-04-11T19:57:36.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'urmy71m3pepv2022041194329',
#    'sender': 'UNIONBANK',
#    'message': 'Acct: **5287\nDR: NGN5,500.00, COM+VAT:26.88\nDesc: MOBILE/UNION Transfer to Chisom Chisom Okpara - NA\nDT: 12/APR/2022 17:00:01\nAvailable Bal: NGN61,113.99CR',
#    'date': '2022-04-12T16:00:44.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'xer7myjf6gl220220415151013',
#    'sender': 'UNIONBANK',
#    'message': 'Be one of 826 customers to win N1,000 airtime this Easter! To qualify, log in to the mobile app or dial *826# now to buy airtime. Hurry! Ts & Cs apply.',
#    'date': '2022-04-16T12:25:24.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'kc31bkdtpmkr2022041591330',
#    'sender': 'UNIONBANK',
#    'message': 'Be one of 826 customers to win N1,000 airtime this Easter! To qualify, log in to the mobile app or dial *826# now to buy airtime. Hurry! Ts & Cs apply.',
#    'date': '2022-04-16T13:03:45.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': '999mibgmrgqq2022046224248',
#    'sender': 'UNIONBANK',
#    'message': 'Be one of 826 customers to win N1,000 airtime this Easter! To qualify, log in to the mobile app or dial *826# now to buy airtime. Hurry! Ts & Cs apply.',
#    'date': '2022-04-18T08:38:19.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'fwui0tkj79un20220414203224',
#    'sender': 'UNIONBANK',
#    'message': 'Be one of 826 customers to win N1,000 airtime this Easter! To qualify, log in to the mobile app or dial *826# now to buy airtime. Hurry! Ts & Cs apply.',
#    'date': '2022-04-18T09:22:09.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'yjmn24lfpmnc20220414143511',
#    'sender': 'UNIONBANK',
#    'message': 'Acct: **2706\nDR: NGN200.00, COM+VAT:107.5\nDesc: UnionMobile/QT PYMT  Fund Wallet/08166061674\nDT: 28/APR/2022 20:21:43\nAvailable Bal: NGN506.95CR',
#    'date': '2022-04-28T19:23:01.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'urmy71m3pepv2022041194329',
#    'sender': 'UNIONBANK',
#    'message': 'Acct: **5287\nDR: NGN60,000.00, COM+VAT:53.75\nDesc: MOBILE/UNION Transfer to KINGSLEY CHINEDU NWIGWE - NA\nDT: 04/MAY/2022 15:42:30\nAvailable Bal: NGN26,074.91CR',
#    'date': '2022-05-04T14:43:46.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'olepkjeq4kqr2022055172755',
#    'sender': 'UNIONBANK',
#    'message': 'Acct: **8232\nDR: NGN5,000.00, COM+VAT:10.75\nDesc: MOBILE/UNION Transfer to CHINWE NANCY ODIBE - NA\nDT: 11/MAY/2022 14:58:24\nAvailable Bal: NGN5,034.15CR',
#    'date': '2022-05-11T13:57:53.000Z'}},
#  {'bank': 'unionbank',
#   'error': ValueError,
#   'input': {'uid': 'vgrfgl8v3yte20220516222324',
#    'sender': 'UNIONBANK',
#    'message': 'Acct: **7244\nDR: NGN200.00, COM+VAT:10.75\nDesc: USSD/UNION Transfer to FAVOUR UKAMAKA OKWURUONYE\nDT: 17/MAY/2022 09:49:47\nAvailable Bal: NGN4,307.25CR',
#    'date': '2022-05-17T08:51:20.000Z'}},
#  {'bank': 'polarisbank',
#   'error': ValueError,
#   'input': {'uid': 'pcuvodxgqq7k2022041284238',
#    'sender': 'PolarisBank',
#    'message': 'Dear Customer, Your One Time Password (OTP) for transaction validation is 043652. The OTP expires in 10 minutes. Thank you',
#    'date': '2022-04-12T07:55:25.000Z'}},
#  {'bank': 'polarisbank',
#   'error': ValueError,
#   'input': {'uid': 'by706vgypp5h202203116505',
#    'sender': 'PolarisBank',
#    'message': 'Be among 10 winners every hour to win double Airtel airtime bonus when you recharge with *833*Amount*PhoneNumber#. T&Cs apply! Enquiries? 08069880000',
#    'date': '2022-04-20T09:24:49.000Z'}},
#  {'bank': 'polarisbank',
#   'error': ValueError,
#   'input': {'uid': 'by706vgypp5h202203116505',
#    'sender': 'PolarisBank',
#    'message': 'Be among 10 winners every hour to win double Airtel airtime bonus when you recharge with *833*Amount*PhoneNumber#. T&Cs apply! Enquiries? 08069880000',
#    'date': '2022-05-04T13:40:21.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'g090urqlqo7k202204873316',
#    'sender': 'AccessBank',
#    'message': 'Your balance on account 00XXXX4161 is: 69.25',
#    'date': '2022-04-09T14:01:39.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'wpj1yulgg3ci20220473314',
#    'sender': 'AccessBank',
#    'message': 'Keep the blessings going this period with an instant loan of up to N300K INSTANTLY! Simply dial #901*11# to get started.',
#    'date': '2022-04-11T09:18:05.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'qmrj6ij5418p2022048155225',
#    'sender': 'AccessBank',
#    'message': 'Your AccessMore user id is: NNANNAOBED. If this was not initiated by you, please call us immediately on 01-2802500 or 0700 CallAccess.',
#    'date': '2022-04-12T15:16:28.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'hxkp8b06y9102022047175629',
#    'sender': 'AccessBank',
#    'message': '"Your account is about to be debited, please approve with OTP: 693440 which expires in 10 minutes or call 01-2712005 to stop the payment"',
#    'date': '2022-04-13T19:26:23.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'hxkp8b06y9102022047175629',
#    'sender': 'AccessBank',
#    'message': '"Your account is about to be debited, please approve with OTP: 796808 which expires in 10 minutes or call 01-2712005 to stop the payment"',
#    'date': '2022-04-13T19:26:49.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'qynztg9ai6ia20220318191612',
#    'sender': 'AccessBank',
#    'message': '"Your account is about to be debited, please approve with OTP: 428532 which expires in 10 minutes or call 01-2712005 to stop the payment"',
#    'date': '2022-04-16T08:49:16.000Z'}},
#  {'bank': 'accessbank',
#   'error': ValueError,
#   'input': {'uid': 'qynztg9ai6ia20220318191612',
#    'sender': 'AccessBank',
#    'message': '"Your account is about to be debited, please approve with OTP: 977473 which expires in 10 minutes or call 01-2712005 to stop the payment"',
#    'date': '2022-04-16T08:50:58.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'c8ow9omcxrjy20220324115358',
#    'sender': 'FirstBank',
#    'message': 'Your Acct 310XXXX607 Has Been Credited with NGN2.00 On 24-MAR-2022 13:09:49 By REV:ONLINE PMNT-MX1049, 3IPG0001//539923. Bal: NGN342.64CR',
#    'date': '2022-03-24T12:07:57.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '13tywc9d9btv202203310323',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 4541. Use 912230 as your One Time Passcode. Expires on 03-Apr-2022 13:32',
#    'date': '2022-04-03T12:23:18.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'pynpo08k18c52022046113338',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6059. Use 079648 as your One Time Passcode. Expires on 06-Apr-2022 12:20',
#    'date': '2022-04-06T11:09:33.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'pynpo08k18c52022046113338',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6059. Use 693968 as your One Time Passcode. Expires on 06-Apr-2022 13:12',
#    'date': '2022-04-06T12:01:11.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'pynpo08k18c52022046113338',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6059. Use 912453 as your One Time Passcode. Expires on 06-Apr-2022 13:13',
#    'date': '2022-04-06T12:02:53.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '1ven5nj0k7ff202204820450',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6136. Use 666235 as your One Time Passcode. Expires on 09-Apr-2022 08:50',
#    'date': '2022-04-09T07:41:02.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '1ven5nj0k7ff202204820450',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6136. Use 714116 as your One Time Passcode. Expires on 09-Apr-2022 09:20',
#    'date': '2022-04-09T08:11:04.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'odphfuryx8pf202204110215',
#    'sender': 'FirstBank',
#    'message': 'Use this OTP 357732 to complete transaction',
#    'date': '2022-04-11T00:33:06.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'gu9op294zfa720220411133758',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 7151. Use 275155 as your One Time Passcode. Expires on 11-Apr-2022 15:30',
#    'date': '2022-04-11T14:19:19.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '9l2edvizs61u2022041120579',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 3718. Use 706859 as your One Time Passcode. Expires on 11-Apr-2022 21:49',
#    'date': '2022-04-11T20:40:22.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '3sc3ls25zvcq2022041411559',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN10.00 on your Account using MasterCard 5438. Use 443774 as your One Time Passcode. Expires on 14-Apr-2022 11:40',
#    'date': '2022-04-14T10:30:59.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '27vcbqf89msi20220119115558',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 3368. Use 969134 as your One Time Passcode. Expires on 15-Apr-2022 15:11',
#    'date': '2022-04-15T14:03:42.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '27vcbqf89msi20220119115558',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 3368. Use 561723 as your One Time Passcode. Expires on 15-Apr-2022 15:16',
#    'date': '2022-04-15T14:06:56.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '3ufjbpk204af202204885044',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 9808. Use 485209 as your One Time Passcode. Expires on 17-Apr-2022 12:25',
#    'date': '2022-04-17T11:16:31.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '4zqadu31qfef202204141911',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 2717. Use 110161 as your One Time Passcode. Expires on 18-Apr-2022 03:23',
#    'date': '2022-04-18T02:14:27.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'div1e9bgtacn2022041194758',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 6008. Use 542741 as your One Time Passcode. Expires on 18-Apr-2022 19:21',
#    'date': '2022-04-18T18:12:15.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'mk7ey3im1wf22022041912658',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 1928. Use 571055 as your One Time Passcode. Expires on 19-Apr-2022 01:42',
#    'date': '2022-04-19T00:33:10.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'mk7ey3im1wf22022041912658',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 1928. Use 451929 as your One Time Passcode. Expires on 19-Apr-2022 01:44',
#    'date': '2022-04-19T00:34:49.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'mk7ey3im1wf22022041912658',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 1928. Use 754978 as your One Time Passcode. Expires on 19-Apr-2022 02:11',
#    'date': '2022-04-19T01:01:57.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'mk7ey3im1wf22022041912658',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 1928. Use 633059 as your One Time Passcode. Expires on 19-Apr-2022 02:17',
#    'date': '2022-04-19T01:08:14.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'tmrhyxir0c0a2022041520162',
#    'sender': 'FirstBank',
#    'message': 'Your balance as at 19-Apr-2022 12:56:08 : 308XXXX512 is NGN131.52; . You First',
#    'date': '2022-04-19T11:56:15.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': 'div1e9bgtacn2022041194758',
#    'sender': 'FirstBank',
#    'message': 'Your balance as at 19-Apr-2022 21:22:35 : 311XXXX819 is NGN109.52; . You First',
#    'date': '2022-04-19T20:22:45.000Z'}},
#  {'bank': 'firstbank',
#   'error': ValueError,
#   'input': {'uid': '83q2lhfuh1vz20220410204042',
#    'sender': 'FirstBank',
#    'message': '*DO NOT DISCLOSE* A pending Debit of NGN50.00 on your Account using MasterCard 4930. Use 488161 as your One Time Passcode. Expires on 20-Apr-2022 09:32',
#    'date': '2022-04-20T08:21:44.000Z'}}]
